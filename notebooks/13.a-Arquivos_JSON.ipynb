# %%
# FIXME

# %% [markdown]
# # **Arquivos JSON**
# ---

# %% [markdown]
# ## Pré-requisitos da aula
#
# - Dicionário
# - Leitura e gravação de arquivos
# ---

# %% [markdown]
# Em uma aula anterior, aprendemos a ler e gravar dados em um arquivo. Em outra aula, vimos como trabalhar com o conceito de dicionários. Nessa aula, iremos aprender sobre **JSON**, ecomo podemos trabalhar com ele unindo os conhecimentos aprendidos nessas duas aulas. Mas, primeiramente...
#
# ## O que é JSON?
# ---
#
# **JSON** é a sigla para **JavaScript Object Notation**, ou em português, **Objeto de Notação JavaScript**. Como alguns devem saber, JavaScript é uma outra linguagem de programação, geralmente usada para trabalhar com o que chamamos de Front-End, que por usa vez é nada mais do que a tela de uma aplicação web. Um objeto JSON possui uma grande força no mundo da programação por conta de suas várias utilidades, e também por conta de sua compatibilidade com outras linguagens de programação, incluíndo Python, como veremos nessa aula.
#
# Sua estrutura é muito parecida, na verdade quase idêntica ao de um dicionário Python, e um pode ser convertido (serializado) em outro. Embora seja um código JavaScript, pode ser isolado em um arquivo separado com a extensão **.json**.
#
# JSON pode ser usado, por exemplo, para guardar configurações de programas. É um arquivo JSON que salva as configurações do VSCode. Ele pode ser usado como um mini banco de dados que pode ser consultado pela aplicação sem a necessidade de um servidor. É o que faremos no exemplo dessa aula.

# %% [markdown]
# ## Lendo arquivo JSON
# ---
#
# O código abaixo representa uma estrutura de um código JSON:

# %%
objeto = {
    "nome":"Fulano de Tal",
    "idade":18,
    "email":"fulano@gmail.com",
    "profissão":"programador"
}

# %% [markdown]
# Repare que é praticamente idêntico a um dicionário Python. Tanto um objeto JSON quanto um arquivo JSON possuem essa mesma estrutura.
#
# Caso tenhamos em nossas mãos um arquivo JSON, podemos criar um código para ler esses dados, e o que é melhor: podemos desserializá-lo em um dicionário Python, o que não era possível com o arquivo TXT que usamos na outra aula. Isso torna os dados muito mais fáceis de se trabalhar.
#
# Vamos, por exemplo, acessar um site que pode gerar uma base de tamanho considerável no formato JSON para que possamos trabalhar em cima dele:
#
# 1. Acesse o site **4devs**: https://www.4devs.com.br/:

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/4devs.png" alt="4 Devs" />
# </div>

# %% [markdown]
# 2. No menu à esquerda, procure por **Gerador de Pessoas**, e clique nele:

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/menu-gerador-pessoas.png" alt="Menu Gerador de Pessoas" />
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/tela-gerador-pessoas.png" alt="Tela Gerador de Pessoas" />
# </div>

# %% [markdown]
# 3. No campo **6. Gerar quantas pessoas? (Máx.:30)**, aumente o número para **30**, e depois clique no botão **GERAR PESSOA**:

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/gerar-pessoa.png" alt="Gerar Pessoa" />
# </div>

# %% [markdown]
# 4. Na mesma página, logo abaixo do botão **GERAR PESSOA**, irá aparecer justamente um código JSON com os dados de 30 pessoas fictícias:

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/resultado-gerador-de-pessoas.png" alt="Resultado Gerador de Pessoas" />
# </div>

# %% [markdown]
# 5. Observe que a tela possui dois botões: **Copiar** e **Download**.
# 6. Antes de mais nada, crie um novo projeto no VSCode e dê a ele o nome que quiser (sugestão: **arquivos_json**).
# 7. Clique no botão **Download** e salve na raíz do seu projeto.

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/download-gerador-de-pessoas.png" alt="Download Gerador de Pessoas" />
# </div>

# %% [markdown]
# 8. O arquivo a ser salvo terá o formato .json:

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/download-data-json.png" alt="Download Data Json" />
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/data-json-baixado.png" alt="data.json baixado" />
# </div>

# %% [markdown]
# 9. No arquivo .py do seu projeto, vamos criar um código para ler o arquivo e serializar os dados em um dicionário Python. Para isso, precisaremos importar uma biblioteca específica para trabalhar com JSON, já que ele não é um código Python, mas não se preocupe, o Python já possui a biblioteca em questão, só precisaremos importá-la dentro do nosso código. Escreva o código abaixo:

# %%
# importa a biblioteca json
import json

# lê o arquivo json e desserializa em um dicionário
with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

# percorre a lista
for i in range(len(dados)):
    # percorre o dicionário de cada lista
    for chave in dados[i]:
        # exibe os dados da lista de dicionários na tela
        print(f"{chave}: {dados[i].get(chave)}.")
    # divide cada item da lista
    print(f"\n{"-"*30}\n")
# Out:
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------

# %% [markdown]
# 10. Observe que a saída do nosso programa são exatamente os dados do objeto JSON, desserializados como um dicionário Python, o que torna os dados do arquivo muito mais fáceis de se manipular do que se eles estivessem gravados em um TXT, já que no TXT eu teria que trabalhar com todos os dados armazenados em uma única variável. Esse detalhe faz fcom que eu possa mais facilmente trabalhar com cada um dos dados de forma separada.

# %% [markdown]
# ## Alterando os dados do arquivo JSON
# ---
#
# Tal como fizemos com o arquivo TXT na outra aula, aqui também podemos alterar os dados do arquivo JSON. Porém, diferente de lá, aqui podemos trabalhar com cada um dos dados de forma separada, evitando assim ter que sobrescrever todo o arquivo. Vamos começar inserindo um novo item na lista, ou melhor dizendo, neste caso, inserindo uma nova pessoa na lista.
#
# ### Inserindo nova pessoa
#
# Vamos criar um dicionário com os dados da nova pessoa, adicioná-los à lista, e gravar no arquivo JSON. Acrescente ao seu arquivo .py o código abaixo:

# %%
# dicionário a ser acrescentado na lista
pessoa = {
    "nome": "Fulano de Tal",
    "idade": 18,
    "cpf": "111.111.111-11",
    "rg": "11.111.111-1",
    "data_nasc": "01/01/1980",
    "sexo": "Masculino",
    "signo": "Gêmeos",
    "mae": "Fulana de Tal",
    "pai": "Fulano Pai",
    "email": "fulano@servidor.com.br",
    "senha": "12345678",
    "cep": "64601-030",
    "endereco": "Rua Parnaíba",
    "numero": 870,
    "bairro": "Paroquial",
    "cidade": "Picos",
    "estado": "PI",
    "telefone_fixo": "(89) 2893-6324",
    "celular": "(89) 99240-0530",
    "altura": "1,85",
    "peso": 100,
    "tipo_sanguineo": "O+",
    "cor": "verde"
}

# insere o dicionário na lista
dados.append(pessoa)

# serializa o dicionário em JSON e grava os novos dados no arquivo
with open("data.json", "w", encoding="utf-8") as f:
    json.dump(dados, f)

# faz uma nova leitura dos dados do arquivo JSON
with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

# reexibe os dados do arquivo JSON na tela. A nova pessoa será a última da lista
for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")
# Out:
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Fulano de Tal.
# idade: 18.
# cpf: 111.111.111-11.
# rg: 11.111.111-1.
# data_nasc: 01/01/1980.
# sexo: Masculino.
# signo: Gêmeos.
# mae: Fulana de Tal.
# pai: Fulano Pai.
# email: fulano@servidor.com.br.
# senha: 12345678.
# cep: 64601-030.
# endereco: Rua Parnaíba.
# numero: 870.
# bairro: Paroquial.
# cidade: Picos.
# estado: PI.
# telefone_fixo: (89) 2893-6324.
# celular: (89) 99240-0530.
# altura: 1,85.
# peso: 100.
# tipo_sanguineo: O+.
# cor: verde.
#
# ------------------------------

# %% [markdown]
# ### Alterando um campo específico
#
# Repare que a pessoa que adicionamos possui um erro nos dados: o signo não corresponde à data de nascimento. Portanto, iremos corrigir esse detalhe.
#
# O arquivo JSON tinha originalmente 30 pessoas. Como o computador começa a contar a lista a partir do número 0 (zero) conforme vimos nas aulas anteriores, ele irá contar do 0 ao 29. Isso significa que a nova pessoa que adicionamos possui um índice de número 30. Esse detalhe é importante para identificarmos a pessoa dentro da lista, e após isso, identificarmos a chave que precisará ser corrigida. No caso, iremos corrigir o campo **signo** do índice de número **30**.
#
# Acrescente o código abaixo ao final do seu arquivo .py:

# %%
# repassa o novo valor ao índice e à chave correspondente
dados[30]["signo"] = "Capricórnio"

# serializa o dicionário em JSON e grava os novos dados no arquivo
with open("data.json", "w", encoding="utf-8") as f:
    json.dump(dados, f)

# faz uma nova leitura dos dados do arquivo JSON
with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

# reexibe os dados do arquivo JSON na tela. A nova pessoa será a última da lista
for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")
# Out:
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Fulano de Tal.
# idade: 18.
# cpf: 111.111.111-11.
# rg: 11.111.111-1.
# data_nasc: 01/01/1980.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fulana de Tal.
# pai: Fulano Pai.
# email: fulano@servidor.com.br.
# senha: 12345678.
# cep: 64601-030.
# endereco: Rua Parnaíba.
# numero: 870.
# bairro: Paroquial.
# cidade: Picos.
# estado: PI.
# telefone_fixo: (89) 2893-6324.
# celular: (89) 99240-0530.
# altura: 1,85.
# peso: 100.
# tipo_sanguineo: O+.
# cor: verde.
#
# ------------------------------

# %% [markdown]
# Veja que o campo **signo** da pessoa de nome **Fulano de Tal** foi alterado para **Capricórnio**.
#
# ### Deletando uma pessoa
#
# Que tal retirarmos o nosso **Fulano de Tal** do nosso arquivo JSON? Façamos isso. Acrescente o código abaixo ao final do seu arquivo .py:

# %%
# deletando usuário
del(dados[30])

# serializa o dicionário em JSON e grava os novos dados no arquivo
with open("data.json", "w", encoding="utf-8") as f:
    json.dump(dados, f)

# faz uma nova leitura dos dados do arquivo JSON
with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

# reexibe os dados do arquivo JSON na tela. A nova pessoa será a última da lista
for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")
# Out:
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------

# %% [markdown]
# Repare que o nosso **Fulano de Tal** sumiu do nosso arquivo JSON. Agora voltamos a ter 30 pessoas: do índice 0 ao 29.
#
# ## Criando um novo arquivo JSON do zero
# ---
#
# Também é possível criar um novo arquivo do zero. O interessante dessa opção é que podemos criar novos arquivos com dados diferentes a cada nova criação.
#
# Para este exemplo, vamos começar com algo simples: vamos criar uma lista com um dicionário dentro, e guardar essa informação dentro de um arquivo que ainda não existe.
#
# Acrescente ao final do seu arquivo .py o código abaixo:

# %%
# lista contendo um dicionário
usuarios = [dict(nome="Cicrano de Souza", cargo="Programador")]

# serializa lista de dicionário em json
objeto_json = json.dumps(usuarios)

# gera um novo arquivo JSON
with open("meu_arquivo.json", "w", encoding="utf-8") as f:
    f.write(objeto_json)

# %% [markdown]
# Observe que foi criado um novo arquivo chamado **meu_arquivo.json** na raíz do seu projeto:

# %% [markdown]
# <div style="display: flex; justify-content: center">
#     <img src="../assets/meu_arquivo_json.png" alt="meu_arquivo.json" />
# </div>

# %% [markdown]
# Abra esse arquivo, e veja que a lista do Python foi gravada nesse novo arquivo. Se quiser que o Python leia esse novo arquivo, acrescente o código abaixo ao final do seu arquivo .py:

# %%
with open("meu_arquivo.json", "r", encoding="utf-8") as f:
    meus_dados = json.load(f)

for i in range(len(meus_dados)):
    for chave in meus_dados[i]:
        print(f"{chave}: {meus_dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")
# Out:
# nome: Cicrano de Souza.
# cargo: Programador.
#
# ------------------------------

# %% [markdown]
# **E é isso!!!**
#
# ## **Código-fonte final**
# ---

# %%
import json

with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")

pessoa = {
    "nome": "Fulano de Tal",
    "idade": 18,
    "cpf": "111.111.111-11",
    "rg": "11.111.111-1",
    "data_nasc": "01/01/1980",
    "sexo": "Masculino",
    "signo": "Gêmeos",
    "mae": "Fulana de Tal",
    "pai": "Fulano Pai",
    "email": "fulano@servidor.com.br",
    "senha": "12345678",
    "cep": "64601-030",
    "endereco": "Rua Parnaíba",
    "numero": 870,
    "bairro": "Paroquial",
    "cidade": "Picos",
    "estado": "PI",
    "telefone_fixo": "(89) 2893-6324",
    "celular": "(89) 99240-0530",
    "altura": "1,85",
    "peso": 100,
    "tipo_sanguineo": "O+",
    "cor": "verde"
}

dados.append(pessoa)

with open("data.json", "w", encoding="utf-8") as f:
    json.dump(dados, f)

with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")

dados[30]["signo"] = "Capricórnio"

with open("data.json", "w", encoding="utf-8") as f:
    json.dump(dados, f)

with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")

del(dados[30])

with open("data.json", "w", encoding="utf-8") as f:
    json.dump(dados, f)

with open("data.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

for i in range(len(dados)):
    for chave in dados[i]:
        print(f"{chave}: {dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")

usuarios = [dict(nome="Cicrano de Souza", cargo="Programador")]
objeto_json = json.dumps(usuarios)

with open("meu_arquivo.json", "w", encoding="utf-8") as f:
    f.write(objeto_json)

with open("meu_arquivo.json", "r", encoding="utf-8") as f:
    meus_dados = json.load(f)

for i in range(len(meus_dados)):
    for chave in meus_dados[i]:
        print(f"{chave}: {meus_dados[i].get(chave)}.")
    print(f"\n{"-"*30}\n")
# Out:
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Fulano de Tal.
# idade: 18.
# cpf: 111.111.111-11.
# rg: 11.111.111-1.
# data_nasc: 01/01/1980.
# sexo: Masculino.
# signo: Gêmeos.
# mae: Fulana de Tal.
# pai: Fulano Pai.
# email: fulano@servidor.com.br.
# senha: 12345678.
# cep: 64601-030.
# endereco: Rua Parnaíba.
# numero: 870.
# bairro: Paroquial.
# cidade: Picos.
# estado: PI.
# telefone_fixo: (89) 2893-6324.
# celular: (89) 99240-0530.
# altura: 1,85.
# peso: 100.
# tipo_sanguineo: O+.
# cor: verde.
#
# ------------------------------
#
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Fulano de Tal.
# idade: 18.
# cpf: 111.111.111-11.
# rg: 11.111.111-1.
# data_nasc: 01/01/1980.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fulana de Tal.
# pai: Fulano Pai.
# email: fulano@servidor.com.br.
# senha: 12345678.
# cep: 64601-030.
# endereco: Rua Parnaíba.
# numero: 870.
# bairro: Paroquial.
# cidade: Picos.
# estado: PI.
# telefone_fixo: (89) 2893-6324.
# celular: (89) 99240-0530.
# altura: 1,85.
# peso: 100.
# tipo_sanguineo: O+.
# cor: verde.
#
# ------------------------------
#
# nome: Betina Mariah Vitória da Rocha.
# idade: 54.
# cpf: 114.270.937-09.
# rg: 27.102.953-5.
# data_nasc: 15/03/1970.
# sexo: Feminino.
# signo: Peixes.
# mae: Natália Maya.
# pai: Julio Leandro da Rocha.
# email: betina.mariah.darocha@poligerma.com.br.
# senha: 4MHLjtrd9M.
# cep: 61642-030.
# endereco: Rua Assunção.
# numero: 884.
# bairro: Parque das Nações (Jurema).
# cidade: Caucaia.
# estado: CE.
# telefone_fixo: (85) 2999-5438.
# celular: (85) 99622-0698.
# altura: 1,70.
# peso: 86.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabelle Andrea Bárbara Carvalho.
# idade: 49.
# cpf: 089.791.274-80.
# rg: 18.435.802-4.
# data_nasc: 24/04/1975.
# sexo: Feminino.
# signo: Touro.
# mae: Luana Raimunda.
# pai: Diogo Ian Nelson Carvalho.
# email: isabelleandreacarvalho@gmnail.com.
# senha: Z2sQ6sZCYd.
# cep: 40490-264.
# endereco: Rua Zé do Violão.
# numero: 531.
# bairro: São João do Cabrito.
# cidade: Salvador.
# estado: BA.
# telefone_fixo: (71) 2685-8798.
# celular: (71) 99537-9024.
# altura: 1,53.
# peso: 63.
# tipo_sanguineo: A+.
# cor: vermelho.
#
# ------------------------------
#
# nome: Augusto Marcos Vinicius Henrique Freitas.
# idade: 37.
# cpf: 991.908.577-47.
# rg: 35.031.332-5.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Yasmin Débora Aline.
# pai: Severino Emanuel Manuel Freitas.
# email: augusto_freitas@gringa360.com.br.
# senha: X2AD7QJDiU.
# cep: 69078-252.
# endereco: Beco Herval Rossano.
# numero: 824.
# bairro: Japiim.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 3830-5624.
# celular: (92) 99749-6290.
# altura: 1,79.
# peso: 71.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Isabel Rebeca Sophia Galvão.
# idade: 75.
# cpf: 629.253.624-60.
# rg: 37.078.363-3.
# data_nasc: 01/04/1949.
# sexo: Feminino.
# signo: Áries.
# mae: Camila Clarice.
# pai: Miguel Juan Galvão.
# email: isabel_rebeca_galvao@email.com.
# senha: WlSHXQO1Ay.
# cep: 29167-617.
# endereco: Beco da Conceição I.
# numero: 442.
# bairro: Taquara II.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3535-0513.
# celular: (27) 98765-3247.
# altura: 1,66.
# peso: 79.
# tipo_sanguineo: A+.
# cor: azul.
#
# ------------------------------
#
# nome: Bianca Sônia Santos.
# idade: 29.
# cpf: 894.260.991-07.
# rg: 36.798.456-8.
# data_nasc: 12/08/1995.
# sexo: Feminino.
# signo: Leão.
# mae: Manuela Carla Isadora.
# pai: Thiago Miguel Santos.
# email: bianca_sonia_santos@poolrescue.com.br.
# senha: iZmWD69Axa.
# cep: 69314-705.
# endereco: Rua CJ-10.
# numero: 308.
# bairro: Jardim Tropical.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 2760-8883.
# celular: (95) 98302-7776.
# altura: 1,57.
# peso: 52.
# tipo_sanguineo: A+.
# cor: roxo.
#
# ------------------------------
#
# nome: Miguel Gustavo Igor Pereira.
# idade: 70.
# cpf: 278.529.492-07.
# rg: 42.272.666-7.
# data_nasc: 14/03/1954.
# sexo: Masculino.
# signo: Peixes.
# mae: Sebastiana Stefany Isadora.
# pai: Mateus Mário Enzo Pereira.
# email: miguel-pereira97@tribunadeindaia.com.br.
# senha: O1gtzlpthG.
# cep: 78138-030.
# endereco: Travessa Nossa Senhora Aparecida.
# numero: 800.
# bairro: Marajoara.
# cidade: Várzea Grande.
# estado: MT.
# telefone_fixo: (65) 3547-3179.
# celular: (65) 98612-8583.
# altura: 1,77.
# peso: 66.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Kevin Mateus Gonçalves.
# idade: 30.
# cpf: 902.252.561-93.
# rg: 43.218.824-1.
# data_nasc: 19/01/1994.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Isabella Emilly Elisa.
# pai: Luiz Ruan Gonçalves.
# email: kevinmateusgoncalves@coreval.com.br.
# senha: GwRNerpd3O.
# cep: 35700-028.
# endereco: Rua Professor Teixeira da Costa.
# numero: 805.
# bairro: Centro.
# cidade: Sete Lagoas.
# estado: MG.
# telefone_fixo: (31) 2733-0543.
# celular: (31) 99261-4344.
# altura: 1,82.
# peso: 102.
# tipo_sanguineo: O-.
# cor: preto.
#
# ------------------------------
#
# nome: Sebastião Julio Assis.
# idade: 79.
# cpf: 101.324.981-03.
# rg: 50.556.503-1.
# data_nasc: 05/01/1945.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Fernanda Rayssa Francisca.
# pai: Edson Ian Assis.
# email: sebastiao_julio_assis@siemens.com.
# senha: RPdoxD2fKd.
# cep: 66640-124.
# endereco: Rua Santo Antonio.
# numero: 943.
# bairro: Mangueirão.
# cidade: Belém.
# estado: PA.
# telefone_fixo: (91) 2842-1012.
# celular: (91) 99916-8061.
# altura: 1,64.
# peso: 52.
# tipo_sanguineo: O-.
# cor: laranja.
#
# ------------------------------
#
# nome: Yasmin Ayla Maya Mendes.
# idade: 69.
# cpf: 021.154.141-95.
# rg: 42.257.018-7.
# data_nasc: 04/10/1955.
# sexo: Feminino.
# signo: Libra.
# mae: Isadora Giovanna Francisca.
# pai: Marcos Matheus Mendes.
# email: yasminaylamendes@live.ie.
# senha: ouoUhdcYW0.
# cep: 69080-560.
# endereco: Beco Gomes.
# numero: 362.
# bairro: Coroado.
# cidade: Manaus.
# estado: AM.
# telefone_fixo: (92) 2926-2739.
# celular: (92) 98117-9533.
# altura: 1,71.
# peso: 49.
# tipo_sanguineo: AB+.
# cor: verde.
#
# ------------------------------
#
# nome: Ian Anderson Cavalcanti.
# idade: 36.
# cpf: 881.385.884-11.
# rg: 49.796.497-1.
# data_nasc: 04/02/1988.
# sexo: Masculino.
# signo: Aquário.
# mae: Eloá Brenda.
# pai: Manoel Renan Cavalcanti.
# email: ianandersoncavalcanti@ceviu.com.br.
# senha: h0u9WdQC0n.
# cep: 49043-624.
# endereco: Rua Doze A.
# numero: 346.
# bairro: Santa Maria.
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 3902-0407.
# celular: (79) 98789-9438.
# altura: 1,84.
# peso: 58.
# tipo_sanguineo: A-.
# cor: verde.
#
# ------------------------------
#
# nome: Edson Victor Oliveira.
# idade: 18.
# cpf: 257.527.363-31.
# rg: 37.143.563-8.
# data_nasc: 21/08/2006.
# sexo: Masculino.
# signo: Leão.
# mae: Marcela Gabriela.
# pai: Gustavo Theo Oliveira.
# email: edson.victor.oliveira@contjulioroberto.com.br.
# senha: AzxgeaZzKT.
# cep: 76801-192.
# endereco: Rua Abunã.
# numero: 466.
# bairro: Arigolândia.
# cidade: Porto Velho.
# estado: RO.
# telefone_fixo: (69) 2671-0234.
# celular: (69) 99455-7854.
# altura: 1,76.
# peso: 93.
# tipo_sanguineo: A-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Rayssa Rafaela Malu da Cruz.
# idade: 52.
# cpf: 284.089.002-00.
# rg: 42.415.978-8.
# data_nasc: 14/08/1972.
# sexo: Feminino.
# signo: Leão.
# mae: Camila Lavínia.
# pai: Luís Raimundo da Cruz.
# email: rayssa-dacruz89@eternalam.com.br.
# senha: OroxOSS83K.
# cep: 89056-101.
# endereco: Rua Fritz Koegler.
# numero: 203.
# bairro: Fortaleza.
# cidade: Blumenau.
# estado: SC.
# telefone_fixo: (47) 2829-2733.
# celular: (47) 98846-8580.
# altura: 1,82.
# peso: 69.
# tipo_sanguineo: A+.
# cor: laranja.
#
# ------------------------------
#
# nome: Márcia Letícia dos Santos.
# idade: 20.
# cpf: 577.228.511-42.
# rg: 49.823.252-9.
# data_nasc: 24/03/2004.
# sexo: Feminino.
# signo: Áries.
# mae: Ana Heloise.
# pai: Alexandre Juan dos Santos.
# email: marcialeticiadossantos@crbrandao.com.br.
# senha: 1tuKg1c0u2.
# cep: 65091-148.
# endereco: Rua Alto da Paz.
# numero: 727.
# bairro: Vila Maranhão.
# cidade: São Luís.
# estado: MA.
# telefone_fixo: (98) 3815-7303.
# celular: (98) 98837-1769.
# altura: 1,79.
# peso: 58.
# tipo_sanguineo: AB-.
# cor: laranja.
#
# ------------------------------
#
# nome: Luan Daniel Kevin da Rosa.
# idade: 80.
# cpf: 636.964.982-11.
# rg: 46.258.039-8.
# data_nasc: 18/05/1944.
# sexo: Masculino.
# signo: Touro.
# mae: Alice Aparecida Caroline.
# pai: Samuel Carlos Eduardo da Rosa.
# email: luan_daniel_darosa@sofisticattomoveis.com.br.
# senha: 3Q1WyxNEXO.
# cep: 58400-085.
# endereco: Praça da Bandeira.
# numero: 689.
# bairro: Centro.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 3544-1160.
# celular: (83) 99693-3621.
# altura: 1,67.
# peso: 98.
# tipo_sanguineo: AB+.
# cor: laranja.
#
# ------------------------------
#
# nome: Cecília Eliane Malu Rezende.
# idade: 56.
# cpf: 325.537.045-00.
# rg: 26.780.750-8.
# data_nasc: 11/03/1968.
# sexo: Feminino.
# signo: Peixes.
# mae: Allana Letícia Alice.
# pai: Hugo Matheus Bento Rezende.
# email: cecilia-rezende89@athoscontabil.com.br.
# senha: YwrI24GwQd.
# cep: 54774-820.
# endereco: Rua O.
# numero: 296.
# bairro: Santa Teresa.
# cidade: Camaragibe.
# estado: PE.
# telefone_fixo: (81) 3869-3379.
# celular: (81) 99890-4348.
# altura: 1,75.
# peso: 84.
# tipo_sanguineo: A-.
# cor: amarelo.
#
# ------------------------------
#
# nome: Breno Vicente Elias Peixoto.
# idade: 61.
# cpf: 967.703.412-04.
# rg: 26.865.314-8.
# data_nasc: 06/03/1963.
# sexo: Masculino.
# signo: Peixes.
# mae: Allana Vera.
# pai: Otávio Edson Emanuel Peixoto.
# email: breno-peixoto82@optovac.com.br.
# senha: fuWW3p4i3X.
# cep: 29169-320.
# endereco: Rua Rio Uruguai.
# numero: 970.
# bairro: Eldorado.
# cidade: Serra.
# estado: ES.
# telefone_fixo: (27) 3524-0904.
# celular: (27) 98661-9676.
# altura: 1,80.
# peso: 101.
# tipo_sanguineo: AB+.
# cor: roxo.
#
# ------------------------------
#
# nome: Isabel Aline Betina Costa.
# idade: 41.
# cpf: 619.925.809-60.
# rg: 45.394.830-3.
# data_nasc: 23/04/1983.
# sexo: Feminino.
# signo: Touro.
# mae: Rafaela Vanessa Emily.
# pai: Danilo Anderson Carlos Eduardo Costa.
# email: isabel-costa86@otimatransportes.com.
# senha: qTPfAJ29QQ.
# cep: 69919-512.
# endereco: Travessa Osvaldo Dilson.
# numero: 487.
# bairro: Jardim Brasil.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3929-7752.
# celular: (68) 99660-0670.
# altura: 1,54.
# peso: 81.
# tipo_sanguineo: B-.
# cor: laranja.
#
# ------------------------------
#
# nome: Esther Lorena Almeida.
# idade: 50.
# cpf: 548.289.863-67.
# rg: 29.694.556-0.
# data_nasc: 16/06/1974.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Juliana Raimunda Sueli.
# pai: Thiago Guilherme Almeida.
# email: esther_lorena_almeida@marktechbr.com.br.
# senha: QSTwSbLDKU.
# cep: 58043-901.
# endereco: Rua da Aurora 274.
# numero: 890.
# bairro: Miramar.
# cidade: João Pessoa.
# estado: PB.
# telefone_fixo: (83) 3884-1147.
# celular: (83) 99782-1316.
# altura: 1,72.
# peso: 66.
# tipo_sanguineo: B-.
# cor: azul.
#
# ------------------------------
#
# nome: Gabriela Aurora Jaqueline Caldeira.
# idade: 80.
# cpf: 287.702.311-76.
# rg: 45.885.046-9.
# data_nasc: 15/06/1944.
# sexo: Feminino.
# signo: Gêmeos.
# mae: Louise Agatha.
# pai: Gustavo Davi Marcos Caldeira.
# email: gabriela_caldeira@inglesasset.com.br.
# senha: I9e6mdwsBh.
# cep: 69316-798.
# endereco: Rua Silo.
# numero: 328.
# bairro: Pintolândia.
# cidade: Boa Vista.
# estado: RR.
# telefone_fixo: (95) 3631-4881.
# celular: (95) 98834-0589.
# altura: 1,55.
# peso: 60.
# tipo_sanguineo: B+.
# cor: preto.
#
# ------------------------------
#
# nome: Julio Benjamin Nicolas Gomes.
# idade: 37.
# cpf: 288.205.239-14.
# rg: 21.394.491-1.
# data_nasc: 14/05/1987.
# sexo: Masculino.
# signo: Touro.
# mae: Luciana Andreia Antonella.
# pai: Giovanni Vicente Carlos Gomes.
# email: julio.benjamin.gomes@heineken.com.br.
# senha: NQDn7U8cxG.
# cep: 70658-335.
# endereco: Quadra SHCES Quadra 1303 Bloco E.
# numero: 586.
# bairro: Cruzeiro Novo.
# cidade: Brasília.
# estado: DF.
# telefone_fixo: (61) 2735-7831.
# celular: (61) 98579-4915.
# altura: 1,95.
# peso: 75.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Vicente Benedito Farias.
# idade: 75.
# cpf: 409.726.640-33.
# rg: 29.541.861-8.
# data_nasc: 09/09/1949.
# sexo: Masculino.
# signo: Virgem.
# mae: Josefa Evelyn Lúcia.
# pai: Levi Erick Farias.
# email: vicente-farias82@ferplast.com.br.
# senha: ZScPQiGhm1.
# cep: 25946-232.
# endereco: Rua Ita.
# numero: 720.
# bairro: Centro.
# cidade: Guapimirim.
# estado: RJ.
# telefone_fixo: (21) 3833-3102.
# celular: (21) 99655-1670.
# altura: 1,63.
# peso: 71.
# tipo_sanguineo: O+.
# cor: azul.
#
# ------------------------------
#
# nome: Matheus Benjamin Vinicius Teixeira.
# idade: 78.
# cpf: 306.195.462-71.
# rg: 30.894.546-3.
# data_nasc: 02/01/1946.
# sexo: Masculino.
# signo: Capricórnio.
# mae: Caroline Jennifer.
# pai: Juan César Teixeira.
# email: matheus-teixeira95@profemme.com.br.
# senha: 33e38YJ8pm.
# cep: 53650-710.
# endereco: Rua Belo Horizonte.
# numero: 431.
# bairro: Vila Rural.
# cidade: Igarassu.
# estado: PE.
# telefone_fixo: (81) 2911-7544.
# celular: (81) 99251-8781.
# altura: 1,75.
# peso: 93.
# tipo_sanguineo: O+.
# cor: roxo.
#
# ------------------------------
#
# nome: Aline Vitória Helena Jesus.
# idade: 69.
# cpf: 372.785.261-59.
# rg: 29.225.289-4.
# data_nasc: 24/02/1955.
# sexo: Feminino.
# signo: Peixes.
# mae: Ester Malu.
# pai: Elias Mário Carlos Eduardo Jesus.
# email: aline_vitoria_jesus@consultorialk.com.br.
# senha: JA8PyMBJxL.
# cep: 74964-700.
# endereco: Rua JI 47.
# numero: 335.
# bairro: Jardim Ipê.
# cidade: Aparecida de Goiânia.
# estado: GO.
# telefone_fixo: (62) 3854-5652.
# celular: (62) 98193-2906.
# altura: 1,54.
# peso: 87.
# tipo_sanguineo: B+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Marli Eloá Araújo.
# idade: 36.
# cpf: 692.679.873-72.
# rg: 19.857.256-6.
# data_nasc: 03/07/1988.
# sexo: Feminino.
# signo: Câncer.
# mae: Heloisa Amanda Ana.
# pai: Carlos Nicolas Araújo.
# email: marli.eloa.araujo@jglima.com.br.
# senha: 7jLU1xKCxP.
# cep: 49004-574.
# endereco: Travessa São Miguel.
# numero: 205.
# bairro: Zona de Expansão (Robalo).
# cidade: Aracaju.
# estado: SE.
# telefone_fixo: (79) 2990-0883.
# celular: (79) 99646-1650.
# altura: 1,54.
# peso: 68.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Alexandre Davi Souza.
# idade: 62.
# cpf: 196.819.374-06.
# rg: 44.466.771-4.
# data_nasc: 11/10/1962.
# sexo: Masculino.
# signo: Libra.
# mae: Juliana Caroline.
# pai: Gustavo Joaquim Levi Souza.
# email: alexandre_souza@serteccontabil.com.br.
# senha: iXLbJRpgXQ.
# cep: 04243-110.
# endereco: Rua Frei Juan Auli.
# numero: 877.
# bairro: Jardim Patente.
# cidade: São Paulo.
# estado: SP.
# telefone_fixo: (11) 2819-4370.
# celular: (11) 99370-8779.
# altura: 1,62.
# peso: 101.
# tipo_sanguineo: O-.
# cor: roxo.
#
# ------------------------------
#
# nome: Luzia Eliane Fabiana Dias.
# idade: 61.
# cpf: 973.754.839-65.
# rg: 26.482.977-3.
# data_nasc: 24/04/1963.
# sexo: Feminino.
# signo: Touro.
# mae: Jéssica Louise.
# pai: Edson Leandro Renato Dias.
# email: luziaelianedias@ruilacos.com.br.
# senha: 0FURot4CO5.
# cep: 44007-400.
# endereco: Travessa Bela Vista.
# numero: 818.
# bairro: Pedra do Descanso.
# cidade: Feira de Santana.
# estado: BA.
# telefone_fixo: (75) 2592-6659.
# celular: (75) 98638-4265.
# altura: 1,71.
# peso: 45.
# tipo_sanguineo: AB+.
# cor: preto.
#
# ------------------------------
#
# nome: José Calebe Raimundo Castro.
# idade: 36.
# cpf: 752.622.186-79.
# rg: 36.147.853-7.
# data_nasc: 26/02/1988.
# sexo: Masculino.
# signo: Peixes.
# mae: Raimunda Pietra Alessandra.
# pai: Ryan Filipe Castro.
# email: jose.calebe.castro@accardoso.com.br.
# senha: OyOyUgibw1.
# cep: 57309-450.
# endereco: Rua José Valeriano da Silva.
# numero: 265.
# bairro: Senador Nilo Coelho.
# cidade: Arapiraca.
# estado: AL.
# telefone_fixo: (82) 3700-9016.
# celular: (82) 99880-8443.
# altura: 1,94.
# peso: 59.
# tipo_sanguineo: B+.
# cor: roxo.
#
# ------------------------------
#
# nome: Heitor Davi Baptista.
# idade: 71.
# cpf: 556.864.497-75.
# rg: 29.228.833-5.
# data_nasc: 18/02/1953.
# sexo: Masculino.
# signo: Aquário.
# mae: Kamilly Jennifer.
# pai: Tiago Paulo Emanuel Baptista.
# email: heitor_baptista@pelozo.com.br.
# senha: bm2jUSDJsq.
# cep: 32185-070.
# endereco: Rua Barão do Rio Branco.
# numero: 509.
# bairro: Nacional.
# cidade: Contagem.
# estado: MG.
# telefone_fixo: (31) 2543-1949.
# celular: (31) 99305-3810.
# altura: 1,77.
# peso: 102.
# tipo_sanguineo: B-.
# cor: roxo.
#
# ------------------------------
#
# nome: Heloise Carolina Vanessa Alves.
# idade: 49.
# cpf: 424.318.949-83.
# rg: 35.108.850-7.
# data_nasc: 12/03/1975.
# sexo: Feminino.
# signo: Peixes.
# mae: Larissa Esther.
# pai: Renan Raimundo Alves.
# email: heloisecarolinaalves@ciaimoveissjc.com.
# senha: uK5RJrY92U.
# cep: 69915-032.
# endereco: Rua dos Engenheiros.
# numero: 467.
# bairro: Conjunto Tangará.
# cidade: Rio Branco.
# estado: AC.
# telefone_fixo: (68) 3926-7086.
# celular: (68) 99660-8800.
# altura: 1,75.
# peso: 55.
# tipo_sanguineo: AB-.
# cor: vermelho.
#
# ------------------------------
#
# nome: Yasmin Lara Sandra Cardoso.
# idade: 50.
# cpf: 384.119.240-84.
# rg: 34.158.853-2.
# data_nasc: 20/02/1974.
# sexo: Feminino.
# signo: Peixes.
# mae: Daiane Isadora Silvana.
# pai: Thiago Anthony Martin Cardoso.
# email: yasmin.lara.cardoso@db9.com.br.
# senha: OJzs923Cnd.
# cep: 58432-587.
# endereco: Rua das Juremas.
# numero: 600.
# bairro: Malvinas.
# cidade: Campina Grande.
# estado: PB.
# telefone_fixo: (83) 2672-3437.
# celular: (83) 98463-9987.
# altura: 1,55.
# peso: 71.
# tipo_sanguineo: AB+.
# cor: amarelo.
#
# ------------------------------
#
# nome: Cicrano de Souza.
# cargo: Programador.
#
# ------------------------------
